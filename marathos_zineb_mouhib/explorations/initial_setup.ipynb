-- %%
CREATE CATALOG IF NOT EXISTS marathos;
CREATE SCHEMA IF NOT EXISTS marathos.bronze;
CREATE SCHEMA IF NOT EXISTS marathos.silver;
CREATE SCHEMA IF NOT EXISTS marathos.gold;

-- %%
CREATE VOLUME IF NOT EXISTS marathos.bronze.raw;

-- %%
DROP TABLE IF EXISTS marathos.silver.obt;

-- %%
DROP TABLE IF EXISTS marathos.bronze.races;
DROP TABLE IF EXISTS workspace.default.obt;
